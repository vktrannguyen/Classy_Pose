# %%
from sklearn import metrics
from sklearn.metrics import precision_recall_curve, auc
import pandas as pd

# %%
df = pd.read_csv('/home/vktrannguyen/Projects/redocked/PLEC/hard_test/results/ANN/ANN_no-tuning_05.csv', sep = ',')
real_class = df['Real_Class']
score = df['Good_Pose_Prob']

# %%
fpr, tpr, thresholds = metrics.roc_curve(real_class, score, pos_label = "Good")
auc(fpr, tpr)
# Out:
# 0.565477821535089

# %%
precision, recall, thresholds = precision_recall_curve(real_class, score, pos_label = "Good")
auc(recall, precision)
# Out:
# 0.11616062218497414

# %%
df = pd.read_csv('/home/vktrannguyen/Projects/redocked/PLEC/hard_test/results/Smina/Smina.csv', sep = ',')
real_class = df['Real_Class']
score = df['Score']

# %% [markdown]
# ### Create PR curves

# %% [markdown]
# #### Nine SFs, ACHE-OTS test set

# %%
df = pd.read_csv('/home/trannguyen/Projects/MLSF-protocol/ACHE/Own_data/MLSF_OTS/genericSFs/ACHE-OTS-Smina.csv', sep = ',')
real_class_1 = df['Real_Class']
score_1 = df['Score']

df = pd.read_csv('/home/trannguyen/Projects/MLSF-protocol/ACHE/Own_data/MLSF_OTS/genericSFs/ACHE-OTS-IFP.csv', sep = ',')
real_class_2 = df['Real_Class']
score_2 = df['Score']

df = pd.read_csv('/home/trannguyen/Projects/MLSF-protocol/ACHE/Own_data/MLSF_OTS/genericSFs/ACHE-OTS-CNN-Score.csv', sep = ',')
real_class_3 = df['Real_Class']
score_3 = df['Score']

df = pd.read_csv('/home/trannguyen/Projects/MLSF-protocol/ACHE/Own_data/MLSF_OTS/genericSFs/ACHE-OTS-RF-Score-VS.csv', sep = ',')
real_class_4 = df['Real_Class']
score_4 = df['Score']

df = pd.read_csv('/home/trannguyen/Projects/MLSF-protocol/ACHE/Own_data/MLSF_OTS/screening/ACHE-OTS-RF-run1.csv', sep = ',')
real_class_5 = df['Real_Class']
score_5 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/MLSF-protocol/ACHE/Own_data/MLSF_OTS/screening/ACHE-OTS-XGB-run1.csv', sep = ',')
real_class_6 = df['Real_Class']
score_6 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/MLSF-protocol/ACHE/Own_data/MLSF_OTS/screening/ACHE-OTS-SVM-run1.csv', sep = ',')
real_class_7 = df['Real_Class']
score_7 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/MLSF-protocol/ACHE/Own_data/MLSF_OTS/screening/ACHE-OTS-ANN-run9.csv', sep = ',')
real_class_8 = df['Real_Class']
score_8 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/MLSF-protocol/ACHE/Own_data/MLSF_OTS/screening/ACHE-OTS-DNN-run1.csv', sep = ',')
real_class_9 = df['Real_Class']
score_9 = df['Active_Prob']

# %%
precision_1, recall_1, thresholds = precision_recall_curve(real_class_1, score_1, pos_label = "Active")
precision_2, recall_2, thresholds = precision_recall_curve(real_class_2, score_2, pos_label = "Active")
precision_3, recall_3, thresholds = precision_recall_curve(real_class_3, score_3, pos_label = "Active")
precision_4, recall_4, thresholds = precision_recall_curve(real_class_4, score_4, pos_label = "Active")
precision_5, recall_5, thresholds = precision_recall_curve(real_class_5, score_5, pos_label = "Active")
precision_6, recall_6, thresholds = precision_recall_curve(real_class_6, score_6, pos_label = "Active")
precision_7, recall_7, thresholds = precision_recall_curve(real_class_7, score_7, pos_label = "Active")
precision_8, recall_8, thresholds = precision_recall_curve(real_class_8, score_8, pos_label = "Active")
precision_9, recall_9, thresholds = precision_recall_curve(real_class_9, score_9, pos_label = "Active")

# %%
y_1=0.136
x_1=0.081
y_2=0
x_2=0
y_3=0.136
x_3=0.081
y_4=0.091
x_4=0.054
y_5=0.727
x_5=0.432
y_6=0.773
x_6=0.459
y_7=0.682
x_7=0.405
y_8=0.636
x_8=0.378
y_9=0.591
x_9=0.351

import matplotlib.pyplot as plt
fig, ax = plt.subplots(dpi=300, figsize=(7,5))
ax.plot(recall_1, precision_1, color='purple')
ax.plot(recall_2, precision_2, color='green')
ax.plot(recall_3, precision_3, color='blue')
ax.plot(recall_4, precision_4, color='brown')
ax.plot(recall_5, precision_5, color='darkorange')
ax.plot(recall_6, precision_6, color='lightcoral')
ax.plot(recall_7, precision_7, color='lightseagreen')
ax.plot(recall_8, precision_8, color='gray')
ax.plot(recall_9, precision_9, color='red')
plt.scatter(x_1, y_1, marker='o', color='purple')
plt.scatter(x_2, y_2, marker='o', color='green')
plt.scatter(x_3, y_3, marker='^', color='blue')
plt.scatter(x_4, y_4, marker='^', color='brown')
plt.scatter(x_5, y_5, marker='s', color='darkorange')
plt.scatter(x_6, y_6, marker='s', color='lightcoral')
plt.scatter(x_7, y_7, marker='s', color='lightseagreen')
plt.scatter(x_8, y_8, marker='s', color='gray')
plt.scatter(x_9, y_9, marker='s', color='red')

#add axis labels to plot
#ax.set_title('Precision-Recall Curve')
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')

#display plot
plt.show()

# %% [markdown]
# #### Nine SFs, PPARA-OTS test set (new)

# %%
df = pd.read_csv('/home/trannguyen/Projects/PPARA-data/option2-NEW-withoutDEKOIS/screening/PPARA-OTS-Smina.csv', sep = ',')
real_class_1 = df['Real_Class']
score_1 = df['Score']

df = pd.read_csv('/home/trannguyen/Projects/PPARA-data/option2-NEW-withoutDEKOIS/screening/PPARA-OTS-IFP.csv', sep = ',')
real_class_2 = df['Real_Class']
score_2 = df['Score']

df = pd.read_csv('/home/trannguyen/Projects/PPARA-data/option2-NEW-withoutDEKOIS/screening/PPARA-OTS-CNN-Score.csv', sep = ',')
real_class_3 = df['Real_Class']
score_3 = df['Score']

df = pd.read_csv('/home/trannguyen/Projects/PPARA-data/option2-NEW-withoutDEKOIS/screening/PPARA-OTS-RF-Score-VS.csv', sep = ',')
real_class_4 = df['Real_Class']
score_4 = df['Score']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/PPARA/screening/PPARA-OTS-RF-run1.csv', sep = ',')
real_class_5 = df['Real_Class']
score_5 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/PPARA/screening/PPARA-OTS-XGB-run1.csv', sep = ',')
real_class_6 = df['Real_Class']
score_6 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/PPARA/screening/PPARA-OTS-SVM-run1.csv', sep = ',')
real_class_7 = df['Real_Class']
score_7 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/PPARA/screening/PPARA-OTS-ANN-run5.csv', sep = ',')
real_class_8 = df['Real_Class']
score_8 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/PPARA/screening/PPARA-OTS-DNN-run6.csv', sep = ',')
real_class_9 = df['Real_Class']
score_9 = df['Active_Prob']

# %%
precision_1, recall_1, thresholds = precision_recall_curve(real_class_1, score_1, pos_label = "Active")
precision_2, recall_2, thresholds = precision_recall_curve(real_class_2, score_2, pos_label = "Active")
precision_3, recall_3, thresholds = precision_recall_curve(real_class_3, score_3, pos_label = "Active")
precision_4, recall_4, thresholds = precision_recall_curve(real_class_4, score_4, pos_label = "Active")
precision_5, recall_5, thresholds = precision_recall_curve(real_class_5, score_5, pos_label = "Active")
precision_6, recall_6, thresholds = precision_recall_curve(real_class_6, score_6, pos_label = "Active")
precision_7, recall_7, thresholds = precision_recall_curve(real_class_7, score_7, pos_label = "Active")
precision_8, recall_8, thresholds = precision_recall_curve(real_class_8, score_8, pos_label = "Active")
precision_9, recall_9, thresholds = precision_recall_curve(real_class_9, score_9, pos_label = "Active")

# %%
y_1=1/24
x_1=0.0125
y_2=0
x_2=0
y_3=0
x_3=0
y_4=1/24
x_4=0.0125
y_5=0
x_5=0
y_6=1/24
x_6=0.0125
y_7=2/24
x_7=0.025
y_8=2/24
x_8=0.025
y_9=1
x_9=0.3

import matplotlib.pyplot as plt
fig, ax = plt.subplots(dpi=300, figsize=(7,5))
ax.plot(recall_1, precision_1, color='purple')
ax.plot(recall_2, precision_2, color='green')
ax.plot(recall_3, precision_3, color='blue')
ax.plot(recall_4, precision_4, color='brown')
ax.plot(recall_5, precision_5, color='darkorange')
ax.plot(recall_6, precision_6, color='lightcoral')
ax.plot(recall_7, precision_7, color='lightseagreen')
ax.plot(recall_8, precision_8, color='gray')
ax.plot(recall_9, precision_9, color='red')
plt.scatter(x_1, y_1, marker='o', color='purple')
plt.scatter(x_2, y_2, marker='o', color='green')
plt.scatter(x_3, y_3, marker='o', color='blue')
plt.scatter(x_4, y_4, marker='o', color='brown')
plt.scatter(x_5, y_5, marker='o', color='darkorange')
plt.scatter(x_6, y_6, marker='o', color='lightcoral')
plt.scatter(x_7, y_7, marker='o', color='lightseagreen')
plt.scatter(x_8, y_8, marker='o', color='gray')
#plt.scatter(x_9, y_9, marker='o', color='red')

#add axis labels to plot
#ax.set_title('Precision-Recall Curve')
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')

#display plot
plt.show()

# %% [markdown]
# #### Four generic SFs, PPARA-DEKOIS test set

# %%
df = pd.read_csv('/home/trannguyen/Projects/MLSF-protocol/PPARA/DEKOIS2.0/PPARA-DEKOIS-Smina.csv', sep = ',')
real_class_1 = df['Real_Class']
score_1 = df['Score']

df = pd.read_csv('/home/trannguyen/Projects/MLSF-protocol/PPARA/DEKOIS2.0/PPARA-DEKOIS-IFP.csv', sep = ',')
real_class_2 = df['Real_Class']
score_2 = df['Score']

df = pd.read_csv('/home/trannguyen/Projects/MLSF-protocol/PPARA/DEKOIS2.0/PPARA-DEKOIS-CNN.csv', sep = ',')
real_class_3 = df['Real_Class']
score_3 = df['Score']

df = pd.read_csv('/home/trannguyen/Projects/MLSF-protocol/PPARA/DEKOIS2.0/PPARA-DEKOIS-RF.csv', sep = ',')
real_class_4 = df['Real_Class']
score_4 = df['Score']

# %%
precision_1, recall_1, thresholds = precision_recall_curve(real_class_1, score_1, pos_label = "Active")
precision_2, recall_2, thresholds = precision_recall_curve(real_class_2, score_2, pos_label = "Active")
precision_3, recall_3, thresholds = precision_recall_curve(real_class_3, score_3, pos_label = "Active")
precision_4, recall_4, thresholds = precision_recall_curve(real_class_4, score_4, pos_label = "Active")

# %%
x_1=0
y_1=0
x_2=0
y_2=0
x_3=0.1
y_3=0.333
x_4=0.125
y_4=0.417

import matplotlib.pyplot as plt
fig, ax = plt.subplots(dpi=300, figsize=(7,5))
ax.plot(recall_1, precision_1, color='purple')
ax.plot(recall_2, precision_2, color='green')
ax.plot(recall_3, precision_3, color='blue')
ax.plot(recall_4, precision_4, color='brown')
plt.scatter(x_1, y_1, marker='o', color='purple')
plt.scatter(x_2, y_2, marker='o', color='green')
plt.scatter(x_3, y_3, marker='^', color='blue')
plt.scatter(x_4, y_4, marker='^', color='brown')

#add axis labels to plot
#ax.set_title('Precision-Recall Curve')
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')

#display plot
plt.show()

# %% [markdown]
# #### Outputting precision-recall tables

# %%
df = pd.read_csv('/home/trannguyen/Projects/MLSF-protocol/PPARA/DEKOIS2.0/PPARA-DEKOIS-CNN.csv', sep = ',')
real_class_10 = df['Real_Class']
score_10 = df['Score']
precision_10, recall_10, thresholds = precision_recall_curve(real_class_10, score_10, pos_label = "Active")
CNNScore_precision_recall_result = pd.DataFrame({"Precision": precision_10, "Recall": recall_10})
CNNScore_precision_recall_result.to_csv("/home/trannguyen/Projects/MLSF-protocol/PPARA/DEKOIS2.0/PPARA-DEKOIS-CNN.txt", index = False)

# %%
df = pd.read_csv('/home/trannguyen/Projects/MLSF-protocol/PPARA/DEKOIS2.0/PPARA-DEKOIS-RF.csv', sep = ',')
real_class_11 = df['Real_Class']
score_11 = df['Score']
precision_11, recall_11, thresholds = precision_recall_curve(real_class_11, score_11, pos_label = "Active")
RFScoreVS_precision_recall_result = pd.DataFrame({"Precision": precision_11, "Recall": recall_11})
RFScoreVS_precision_recall_result.to_csv("/home/trannguyen/Projects/MLSF-protocol/PPARA/DEKOIS2.0/PPARA-DEKOIS-RF.txt", index = False)

# %% [markdown]
# #### DNN-based target-specific ML SF, HMGR-DEKOIS-AVE test set

# %%
df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option3-DEKOIS-AVE/screening/HMGR-DEKOIS-AVE-DNN-run1.csv', sep = ',')
real_class_1 = df['Real_Class']
score_1 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option3-DEKOIS-AVE/screening/HMGR-DEKOIS-AVE-DNN-run2.csv', sep = ',')
real_class_2 = df['Real_Class']
score_2 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option3-DEKOIS-AVE/screening/HMGR-DEKOIS-AVE-DNN-run3.csv', sep = ',')
real_class_3 = df['Real_Class']
score_3 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option3-DEKOIS-AVE/screening/HMGR-DEKOIS-AVE-DNN-run4.csv', sep = ',')
real_class_4 = df['Real_Class']
score_4 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option3-DEKOIS-AVE/screening/HMGR-DEKOIS-AVE-DNN-run5.csv', sep = ',')
real_class_5 = df['Real_Class']
score_5 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option3-DEKOIS-AVE/screening/HMGR-DEKOIS-AVE-DNN-run6.csv', sep = ',')
real_class_6 = df['Real_Class']
score_6 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option3-DEKOIS-AVE/screening/HMGR-DEKOIS-AVE-DNN-run7.csv', sep = ',')
real_class_7 = df['Real_Class']
score_7 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option3-DEKOIS-AVE/screening/HMGR-DEKOIS-AVE-DNN-run8.csv', sep = ',')
real_class_8 = df['Real_Class']
score_8 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option3-DEKOIS-AVE/screening/HMGR-DEKOIS-AVE-DNN-run9.csv', sep = ',')
real_class_9 = df['Real_Class']
score_9 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option3-DEKOIS-AVE/screening/HMGR-DEKOIS-AVE-DNN-run10.csv', sep = ',')
real_class_10 = df['Real_Class']
score_10 = df['Active_Prob']

# %%
precision_1, recall_1, thresholds = precision_recall_curve(real_class_1, score_1, pos_label = "Active")
precision_2, recall_2, thresholds = precision_recall_curve(real_class_2, score_2, pos_label = "Active")
precision_3, recall_3, thresholds = precision_recall_curve(real_class_3, score_3, pos_label = "Active")
precision_4, recall_4, thresholds = precision_recall_curve(real_class_4, score_4, pos_label = "Active")
precision_5, recall_5, thresholds = precision_recall_curve(real_class_5, score_5, pos_label = "Active")
precision_6, recall_6, thresholds = precision_recall_curve(real_class_6, score_6, pos_label = "Active")
precision_7, recall_7, thresholds = precision_recall_curve(real_class_7, score_7, pos_label = "Active")
precision_8, recall_8, thresholds = precision_recall_curve(real_class_8, score_8, pos_label = "Active")
precision_9, recall_9, thresholds = precision_recall_curve(real_class_9, score_9, pos_label = "Active")
precision_10, recall_10, thresholds = precision_recall_curve(real_class_10, score_10, pos_label = "Active")

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(recall_1, precision_1, color='purple')
ax.plot(recall_2, precision_2, color='green')
ax.plot(recall_3, precision_3, color='blue')
ax.plot(recall_4, precision_4, color='darkorange')
ax.plot(recall_5, precision_5, color='brown')
ax.plot(recall_6, precision_6, color='dimgray')
ax.plot(recall_7, precision_7, color='red')
ax.plot(recall_8, precision_8, color='deeppink')
ax.plot(recall_9, precision_9, color='black')
ax.plot(recall_10, precision_10, color='midnightblue')

#add axis labels to plot
ax.set_title('Precision-Recall Curve')
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')

#display plot
plt.show()

# %% [markdown]
# #### DNN-based target-specific ML SF, HMGR-OTS test set

# %%
df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option2-withoutDEKOIS/screening/HMGR-OTS-DNN-run1.csv', sep = ',')
real_class_1 = df['Real_Class']
score_1 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option2-withoutDEKOIS/screening/HMGR-OTS-DNN-run2.csv', sep = ',')
real_class_2 = df['Real_Class']
score_2 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option2-withoutDEKOIS/screening/HMGR-OTS-DNN-run3.csv', sep = ',')
real_class_3 = df['Real_Class']
score_3 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option2-withoutDEKOIS/screening/HMGR-OTS-DNN-run4.csv', sep = ',')
real_class_4 = df['Real_Class']
score_4 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option2-withoutDEKOIS/screening/HMGR-OTS-DNN-run5.csv', sep = ',')
real_class_5 = df['Real_Class']
score_5 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option2-withoutDEKOIS/screening/HMGR-OTS-DNN-run6.csv', sep = ',')
real_class_6 = df['Real_Class']
score_6 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option2-withoutDEKOIS/screening/HMGR-OTS-DNN-run7.csv', sep = ',')
real_class_7 = df['Real_Class']
score_7 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option2-withoutDEKOIS/screening/HMGR-OTS-DNN-run8.csv', sep = ',')
real_class_8 = df['Real_Class']
score_8 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option2-withoutDEKOIS/screening/HMGR-OTS-DNN-run9.csv', sep = ',')
real_class_9 = df['Real_Class']
score_9 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option2-withoutDEKOIS/screening/HMGR-OTS-DNN-run10.csv', sep = ',')
real_class_10 = df['Real_Class']
score_10 = df['Active_Prob']

# %%
precision_1, recall_1, thresholds = precision_recall_curve(real_class_1, score_1, pos_label = "Active")
precision_2, recall_2, thresholds = precision_recall_curve(real_class_2, score_2, pos_label = "Active")
precision_3, recall_3, thresholds = precision_recall_curve(real_class_3, score_3, pos_label = "Active")
precision_4, recall_4, thresholds = precision_recall_curve(real_class_4, score_4, pos_label = "Active")
precision_5, recall_5, thresholds = precision_recall_curve(real_class_5, score_5, pos_label = "Active")
precision_6, recall_6, thresholds = precision_recall_curve(real_class_6, score_6, pos_label = "Active")
precision_7, recall_7, thresholds = precision_recall_curve(real_class_7, score_7, pos_label = "Active")
precision_8, recall_8, thresholds = precision_recall_curve(real_class_8, score_8, pos_label = "Active")
precision_9, recall_9, thresholds = precision_recall_curve(real_class_9, score_9, pos_label = "Active")
precision_10, recall_10, thresholds = precision_recall_curve(real_class_10, score_10, pos_label = "Active")

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(recall_1, precision_1, color='purple')
ax.plot(recall_2, precision_2, color='green')
ax.plot(recall_3, precision_3, color='blue')
ax.plot(recall_4, precision_4, color='darkorange')
ax.plot(recall_5, precision_5, color='brown')
ax.plot(recall_6, precision_6, color='dimgray')
ax.plot(recall_7, precision_7, color='red')
ax.plot(recall_8, precision_8, color='deeppink')
ax.plot(recall_9, precision_9, color='black')
ax.plot(recall_10, precision_10, color='midnightblue')

#add axis labels to plot
ax.set_title('Precision-Recall Curve')
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')

#display plot
plt.show()

# %% [markdown]
# #### DNN-based target-specific ML SF, HMGR-PETS test set

# %%
df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option1-withDEKOIS/screening/HMGR-PETS-DNN-run1.csv', sep = ',')
real_class_1 = df['Real_Class']
score_1 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option1-withDEKOIS/screening/HMGR-PETS-DNN-run2.csv', sep = ',')
real_class_2 = df['Real_Class']
score_2 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option1-withDEKOIS/screening/HMGR-PETS-DNN-run3.csv', sep = ',')
real_class_3 = df['Real_Class']
score_3 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option1-withDEKOIS/screening/HMGR-PETS-DNN-run4.csv', sep = ',')
real_class_4 = df['Real_Class']
score_4 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option1-withDEKOIS/screening/HMGR-PETS-DNN-run5.csv', sep = ',')
real_class_5 = df['Real_Class']
score_5 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option1-withDEKOIS/screening/HMGR-PETS-DNN-run6.csv', sep = ',')
real_class_6 = df['Real_Class']
score_6 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option1-withDEKOIS/screening/HMGR-PETS-DNN-run7.csv', sep = ',')
real_class_7 = df['Real_Class']
score_7 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option1-withDEKOIS/screening/HMGR-PETS-DNN-run8.csv', sep = ',')
real_class_8 = df['Real_Class']
score_8 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option1-withDEKOIS/screening/HMGR-PETS-DNN-run9.csv', sep = ',')
real_class_9 = df['Real_Class']
score_9 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/HMDH/option1-withDEKOIS/screening/HMGR-PETS-DNN-run10.csv', sep = ',')
real_class_10 = df['Real_Class']
score_10 = df['Active_Prob']

# %%
precision_1, recall_1, thresholds = precision_recall_curve(real_class_1, score_1, pos_label = "Active")
precision_2, recall_2, thresholds = precision_recall_curve(real_class_2, score_2, pos_label = "Active")
precision_3, recall_3, thresholds = precision_recall_curve(real_class_3, score_3, pos_label = "Active")
precision_4, recall_4, thresholds = precision_recall_curve(real_class_4, score_4, pos_label = "Active")
precision_5, recall_5, thresholds = precision_recall_curve(real_class_5, score_5, pos_label = "Active")
precision_6, recall_6, thresholds = precision_recall_curve(real_class_6, score_6, pos_label = "Active")
precision_7, recall_7, thresholds = precision_recall_curve(real_class_7, score_7, pos_label = "Active")
precision_8, recall_8, thresholds = precision_recall_curve(real_class_8, score_8, pos_label = "Active")
precision_9, recall_9, thresholds = precision_recall_curve(real_class_9, score_9, pos_label = "Active")
precision_10, recall_10, thresholds = precision_recall_curve(real_class_10, score_10, pos_label = "Active")

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(recall_1, precision_1, color='purple')
ax.plot(recall_2, precision_2, color='green')
ax.plot(recall_3, precision_3, color='blue')
ax.plot(recall_4, precision_4, color='darkorange')
ax.plot(recall_5, precision_5, color='brown')
ax.plot(recall_6, precision_6, color='dimgray')
ax.plot(recall_7, precision_7, color='red')
ax.plot(recall_8, precision_8, color='deeppink')
ax.plot(recall_9, precision_9, color='black')
ax.plot(recall_10, precision_10, color='midnightblue')

#add axis labels to plot
ax.set_title('Precision-Recall Curve')
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')

#display plot
plt.show()

# %% [markdown]
# #### DNN-based target-specific ML SF, ACHE-DEKOIS-AVE test set

# %%
df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option3-DEKOIS-AVE/screening/ACHE-DEKOIS-AVE-DNN-run1.csv', sep = ',')
real_class_1 = df['Real_Class']
score_1 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option3-DEKOIS-AVE/screening/ACHE-DEKOIS-AVE-DNN-run2.csv', sep = ',')
real_class_2 = df['Real_Class']
score_2 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option3-DEKOIS-AVE/screening/ACHE-DEKOIS-AVE-DNN-run3.csv', sep = ',')
real_class_3 = df['Real_Class']
score_3 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option3-DEKOIS-AVE/screening/ACHE-DEKOIS-AVE-DNN-run4.csv', sep = ',')
real_class_4 = df['Real_Class']
score_4 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option3-DEKOIS-AVE/screening/ACHE-DEKOIS-AVE-DNN-run5.csv', sep = ',')
real_class_5 = df['Real_Class']
score_5 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option3-DEKOIS-AVE/screening/ACHE-DEKOIS-AVE-DNN-run6.csv', sep = ',')
real_class_6 = df['Real_Class']
score_6 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option3-DEKOIS-AVE/screening/ACHE-DEKOIS-AVE-DNN-run7.csv', sep = ',')
real_class_7 = df['Real_Class']
score_7 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option3-DEKOIS-AVE/screening/ACHE-DEKOIS-AVE-DNN-run8.csv', sep = ',')
real_class_8 = df['Real_Class']
score_8 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option3-DEKOIS-AVE/screening/ACHE-DEKOIS-AVE-DNN-run9.csv', sep = ',')
real_class_9 = df['Real_Class']
score_9 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option3-DEKOIS-AVE/screening/ACHE-DEKOIS-AVE-DNN-run10.csv', sep = ',')
real_class_10 = df['Real_Class']
score_10 = df['Active_Prob']

# %%
precision_1, recall_1, thresholds = precision_recall_curve(real_class_1, score_1, pos_label = "Active")
precision_2, recall_2, thresholds = precision_recall_curve(real_class_2, score_2, pos_label = "Active")
precision_3, recall_3, thresholds = precision_recall_curve(real_class_3, score_3, pos_label = "Active")
precision_4, recall_4, thresholds = precision_recall_curve(real_class_4, score_4, pos_label = "Active")
precision_5, recall_5, thresholds = precision_recall_curve(real_class_5, score_5, pos_label = "Active")
precision_6, recall_6, thresholds = precision_recall_curve(real_class_6, score_6, pos_label = "Active")
precision_7, recall_7, thresholds = precision_recall_curve(real_class_7, score_7, pos_label = "Active")
precision_8, recall_8, thresholds = precision_recall_curve(real_class_8, score_8, pos_label = "Active")
precision_9, recall_9, thresholds = precision_recall_curve(real_class_9, score_9, pos_label = "Active")
precision_10, recall_10, thresholds = precision_recall_curve(real_class_10, score_10, pos_label = "Active")

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(recall_1, precision_1, color='purple')
ax.plot(recall_2, precision_2, color='green')
ax.plot(recall_3, precision_3, color='blue')
ax.plot(recall_4, precision_4, color='darkorange')
ax.plot(recall_5, precision_5, color='brown')
ax.plot(recall_6, precision_6, color='dimgray')
ax.plot(recall_7, precision_7, color='red')
ax.plot(recall_8, precision_8, color='deeppink')
ax.plot(recall_9, precision_9, color='black')
ax.plot(recall_10, precision_10, color='midnightblue')

#add axis labels to plot
ax.set_title('Precision-Recall Curve')
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')

#display plot
plt.show()

# %% [markdown]
# #### DNN-based target-specific ML SF, ACHE-OTS test set

# %%
df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option2-withoutDEKOIS/screening/ACHE-OTS-DNN-run1.csv', sep = ',')
real_class_1 = df['Real_Class']
score_1 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option2-withoutDEKOIS/screening/ACHE-OTS-DNN-run2.csv', sep = ',')
real_class_2 = df['Real_Class']
score_2 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option2-withoutDEKOIS/screening/ACHE-OTS-DNN-run3.csv', sep = ',')
real_class_3 = df['Real_Class']
score_3 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option2-withoutDEKOIS/screening/ACHE-OTS-DNN-run4.csv', sep = ',')
real_class_4 = df['Real_Class']
score_4 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option2-withoutDEKOIS/screening/ACHE-OTS-DNN-run5.csv', sep = ',')
real_class_5 = df['Real_Class']
score_5 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option2-withoutDEKOIS/screening/ACHE-OTS-DNN-run6.csv', sep = ',')
real_class_6 = df['Real_Class']
score_6 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option2-withoutDEKOIS/screening/ACHE-OTS-DNN-run7.csv', sep = ',')
real_class_7 = df['Real_Class']
score_7 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option2-withoutDEKOIS/screening/ACHE-OTS-DNN-run8.csv', sep = ',')
real_class_8 = df['Real_Class']
score_8 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option2-withoutDEKOIS/screening/ACHE-OTS-DNN-run9.csv', sep = ',')
real_class_9 = df['Real_Class']
score_9 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option2-withoutDEKOIS/screening/ACHE-OTS-DNN-run10.csv', sep = ',')
real_class_10 = df['Real_Class']
score_10 = df['Active_Prob']

# %%
precision_1, recall_1, thresholds = precision_recall_curve(real_class_1, score_1, pos_label = "Active")
precision_2, recall_2, thresholds = precision_recall_curve(real_class_2, score_2, pos_label = "Active")
precision_3, recall_3, thresholds = precision_recall_curve(real_class_3, score_3, pos_label = "Active")
precision_4, recall_4, thresholds = precision_recall_curve(real_class_4, score_4, pos_label = "Active")
precision_5, recall_5, thresholds = precision_recall_curve(real_class_5, score_5, pos_label = "Active")
precision_6, recall_6, thresholds = precision_recall_curve(real_class_6, score_6, pos_label = "Active")
precision_7, recall_7, thresholds = precision_recall_curve(real_class_7, score_7, pos_label = "Active")
precision_8, recall_8, thresholds = precision_recall_curve(real_class_8, score_8, pos_label = "Active")
precision_9, recall_9, thresholds = precision_recall_curve(real_class_9, score_9, pos_label = "Active")
precision_10, recall_10, thresholds = precision_recall_curve(real_class_10, score_10, pos_label = "Active")

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(recall_1, precision_1, color='purple')
ax.plot(recall_2, precision_2, color='green')
ax.plot(recall_3, precision_3, color='blue')
ax.plot(recall_4, precision_4, color='darkorange')
ax.plot(recall_5, precision_5, color='brown')
ax.plot(recall_6, precision_6, color='dimgray')
ax.plot(recall_7, precision_7, color='red')
ax.plot(recall_8, precision_8, color='deeppink')
ax.plot(recall_9, precision_9, color='black')
ax.plot(recall_10, precision_10, color='midnightblue')

#add axis labels to plot
ax.set_title('Precision-Recall Curve')
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')

#display plot
plt.show()

# %% [markdown]
# #### DNN-based target-specific ML SF, ACHE-PETS test set

# %%
df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option1-withDEKOIS/screening/ACHE-PETS-DNN-run1.csv', sep = ',')
real_class_1 = df['Real_Class']
score_1 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option1-withDEKOIS/screening/ACHE-PETS-DNN-run2.csv', sep = ',')
real_class_2 = df['Real_Class']
score_2 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option1-withDEKOIS/screening/ACHE-PETS-DNN-run3.csv', sep = ',')
real_class_3 = df['Real_Class']
score_3 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option1-withDEKOIS/screening/ACHE-PETS-DNN-run4.csv', sep = ',')
real_class_4 = df['Real_Class']
score_4 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option1-withDEKOIS/screening/ACHE-PETS-DNN-run5.csv', sep = ',')
real_class_5 = df['Real_Class']
score_5 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option1-withDEKOIS/screening/ACHE-PETS-DNN-run6.csv', sep = ',')
real_class_6 = df['Real_Class']
score_6 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option1-withDEKOIS/screening/ACHE-PETS-DNN-run7.csv', sep = ',')
real_class_7 = df['Real_Class']
score_7 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option1-withDEKOIS/screening/ACHE-PETS-DNN-run8.csv', sep = ',')
real_class_8 = df['Real_Class']
score_8 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option1-withDEKOIS/screening/ACHE-PETS-DNN-run9.csv', sep = ',')
real_class_9 = df['Real_Class']
score_9 = df['Active_Prob']

df = pd.read_csv('/home/trannguyen/Projects/Jupyter/Classification-MLSFs/ACES/option1-withDEKOIS/screening/ACHE-PETS-DNN-run10.csv', sep = ',')
real_class_10 = df['Real_Class']
score_10 = df['Active_Prob']

# %%
precision_1, recall_1, thresholds = precision_recall_curve(real_class_1, score_1, pos_label = "Active")
precision_2, recall_2, thresholds = precision_recall_curve(real_class_2, score_2, pos_label = "Active")
precision_3, recall_3, thresholds = precision_recall_curve(real_class_3, score_3, pos_label = "Active")
precision_4, recall_4, thresholds = precision_recall_curve(real_class_4, score_4, pos_label = "Active")
precision_5, recall_5, thresholds = precision_recall_curve(real_class_5, score_5, pos_label = "Active")
precision_6, recall_6, thresholds = precision_recall_curve(real_class_6, score_6, pos_label = "Active")
precision_7, recall_7, thresholds = precision_recall_curve(real_class_7, score_7, pos_label = "Active")
precision_8, recall_8, thresholds = precision_recall_curve(real_class_8, score_8, pos_label = "Active")
precision_9, recall_9, thresholds = precision_recall_curve(real_class_9, score_9, pos_label = "Active")
precision_10, recall_10, thresholds = precision_recall_curve(real_class_10, score_10, pos_label = "Active")

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(recall_1, precision_1, color='purple')
ax.plot(recall_2, precision_2, color='green')
ax.plot(recall_3, precision_3, color='blue')
ax.plot(recall_4, precision_4, color='darkorange')
ax.plot(recall_5, precision_5, color='brown')
ax.plot(recall_6, precision_6, color='dimgray')
ax.plot(recall_7, precision_7, color='red')
ax.plot(recall_8, precision_8, color='deeppink')
ax.plot(recall_9, precision_9, color='black')
ax.plot(recall_10, precision_10, color='midnightblue')

#add axis labels to plot
ax.set_title('Precision-Recall Curve')
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')

#display plot
plt.show()
